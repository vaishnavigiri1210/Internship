# %% [markdown]
# Feature Selection in Machine Learning (ML) is the process of selecting the most important input features (variables) from a dataset and removing unnecessary or irrelevant ones.
#
# ### Why Feature Selection is Important
# Improves Accuracy
# Removes noise → model learns better patterns.
# Reduces Overfitting
# Less irrelevant data → model generalizes better.
# Faster Training
# Fewer features → less computation time.
# Better Interpretability
# Easier to understand the model.
#
# ### Types of Feature Selection Methods
#
# 1. Filter Methods (Statistical Approach)
#
# Features are selected based on statistical tests.
# it does not involoves any model only feature importance is calculated based on statistical measures.
#
# ✔ Fast and simple
# ✔ Independent of ML model
#
# Examples:
# - Correlation (remove highly correlated features)  => in this type of feature selection, we check the correlation between features and remove one of them if they are highly correlated.
#
# - Chi-Square Test  => in this type of feature selection, we check the feature independence on the target variable and select the features that are most relevant to the target variable.
#
# ANOVA  => in this type of feature selection, we check the variance between groups and select the features that have the highest variance.(means it checks difference between groups)
# Information Gain
#
# 👉 Example:
# If two features (Age & Birth Year) are highly correlated → keep only one.
#
# 2. Wrapper Methods (Model-Based)
#
# Uses ML model performance to select features.
#
# ✔ More accurate
# ❌ Computationally expensive
#
# Techniques:
#
# - Forward Selection  => start with no features and add one by one based on model performance.
#
# - Backward Elimination  => start with all features and remove one by one based on model performance.
#
# - Recursive Feature Elimination (RFE)  => iteratively removes features and builds a model on those features that remain.(least important features are removed)
#
# 👉 Example:
# Add/remove features step-by-step and check model accuracy.
#
# 3. Embedded Methods (Built-in Selection)
#
# Feature selection happens during model training.
#
# ✔ Balanced (accuracy + speed)
#
# Examples:
#
# - Lasso Regression (L1 Regularization)  => shrinks less important feature coefficients to zero, effectively removing them.
#
# - Decision Trees  => automatically select important features based on splits.
#
# - Random Forest  => feature importance is calculated based on how much each feature decreases impurity.
#
# 👉 Example:
# In Decision Tree, less important features are automatically ignored.
#
# ### Feature Selection vs Feature Extraction
#
# | Feature Selection         | Feature Extraction   |
# | ------------------------- | -------------------- |
# | Selects existing features | Creates new features |
# | Keeps original meaning    | Transforms data      |
# | Example: Remove column    | Example: PCA         |
#
# 🔹 Real-Life Example
#
# In Fake News Detection Project:
#
# Dataset features:
#
# Text length
# Word frequency
# Source credibility
# Number of exclamation marks
#
# 👉 Feature Selection will:
#
# Remove useless features (e.g., random ID column)
# Keep important ones (e.g., word patterns)
#
# ### When to Use Feature Selection
# Large dataset with many features
# Model is slow
# Accuracy is low due to noise
# Overfitting problem

# %%
import pandas as pd     # dataset handle
import numpy as np      # numerical operations
import matplotlib.pyplot as plt     # data visualization

# %%
# Load dataset
df = pd.read_csv("Social_Network_Ads.csv")

# Show first 5 rows
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
# Dataset info
df.info()

# Check missing values
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 15.8+ KB
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
# Remove User ID (useless feature)
df = df.drop('User ID', axis=1)

# %%
from sklearn.preprocessing import LabelEncoder  # text->numbers

# %%
# Convert Gender into numbers
le = LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])

# %%
# Features (input)
X = df.drop('Purchased', axis=1)

# Target (output)
y = df['Purchased']

# %%
from sklearn.preprocessing import StandardScaler  # feature scaling mean=0, std=1

# %%
# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.feature_selection import SelectKBest   # selects useful input features

# %%
from sklearn.feature_selection import f_classif  # feature selection method

# %%
# Select top 2 important features
selector = SelectKBest(score_func=f_classif, k=2)       # k=number of features to select

X_new = selector.fit_transform(X_scaled, y)

print("Selected Features:", selector.get_support()) # which features were selected (True/False)
# Out:
# Selected Features: [False  True  True]

# %%
from sklearn.model_selection import train_test_split  # split data

# %%
# Split data
X_train, X_test, y_train, y_test = train_test_split(
    X_new, y, test_size=0.2, random_state=42
)

# %%
from sklearn.linear_model import LogisticRegression  # classification model

# %%
# Create model
model = LogisticRegression()

# Train model
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Predict
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
# Check accuracy
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8625

# %%
from sklearn.metrics import confusion_matrix

# %%
# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[50  2]
#  [ 9 19]]

# %%
# 1. FILTER METHOD (SelectKBest)

from sklearn.feature_selection import SelectKBest, f_classif

# Apply SelectKBest
selector = SelectKBest(score_func=f_classif, k=2)

X_new = selector.fit_transform(X_scaled, y)

print(selector.get_support())
# Out:
# [False  True  True]

# %%
# 2. WRAPPER METHOD (RFE)

from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# Model
model = LogisticRegression()

# Apply RFE
rfe = RFE(model, n_features_to_select=2)

X_rfe = rfe.fit_transform(X_scaled, y)

print(rfe.support_)
# Out:
# [False  True  True]

# %%
# 3. EMBEDDED METHOD (Lasso)

from sklearn.linear_model import LogisticRegression

# L1 penalty = Lasso type
model = LogisticRegression(penalty='l1', solver='liblinear')

model.fit(X_scaled, y)

print(model.coef_)
# Out:
# [[0.13206375 2.35704503 1.17067483]]
# c:\Users\Vaishnavi Giri\Desktop\@GPP\Internship\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Vaishnavi Giri\Desktop\@GPP\Internship\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1160: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
