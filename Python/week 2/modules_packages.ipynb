# %% [markdown]
# Date: 25/12/2025

# %% [markdown]
# ### Modules
# - Modules are used to categorize code in python into smaller part.
# - A module is simply a file,where  classes,functions and variables are defined.
# - Grouping similar code into a single file makes it easy to access.
#
# Types:
# - System Modules
# - User defined modules
#
# Advantages:
# 1. Reusability: module can be used in some other python code.Hence it provides the facility of code reusabilty.
# 2. Categorization: Similar type of attributes can be placed in one module.
#
# Using system modules:
#
# - import keyword
# - import as
# - from import

# %%
import math
print(math.sin(67))
# Out:
# -0.8555199789753223

# %%
print(math.log(67))
# Out:
# 4.204692619390966

# %%
print(math.sqrt(67))
# Out:
# 8.18535277187245

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
print(math.e)
# Out:
# 2.718281828459045

# %%
import math as m        #import using alias
print(m.sin(90))
# Out:
# 0.8939966636005579

# %%
print(m.log(90))
# Out:
# 4.499809670330265

# %%
from math import sin, log, pi   #import specific functions from a module also known as selective import
print(sin(55))
# Out:
# -0.9997551733586199

# %%
print(log(55))
# Out:
# 4.007333185232471

# %%
print(pi)
# Out:
# 3.141592653589793

# %% [markdown]
# ### User Defined modules
# - Any program stored in current working directory can be imported by import statement.
# - When such program(module) is imported, we can use all functions,classes and global variables from that program in your program.
# - The import,import...as and from...import will work in the same fashion.
# - It creates a python compiled file with extension .pyc in current working directory
#
# for example see:
# - C:\Users\Vaishnavi Giri\Desktop\@GPP\Internship\Python\week 2\user_defined_module.py
# - C:\Users\Vaishnavi Giri\Desktop\@GPP\Internship\Python\week 2\main.py

# %% [markdown]
# ### Pyhton Package
#
# - A Package is simply a collection of similar modules, sub-packages etc..
#
# Steps to create and import Package:
#
# 1) Create a directory, say Info
# 2) Place different modules inside the directory. We are placing 3 modules msgl.py, msg2.py and msg3.py respectively and place corresponding codes in respective modules. Let us place msg1() in msg1.py, msg2() in msg2.py and msg3() in msg3.py.
# 3) Create a file __init__.py which specifies attributes in each module.
# 4) Import the package and use the attributes using package.
#
# for example see:
# - C:\Users\Vaishnavi Giri\Desktop\@GPP\Internship\Python\week 2\package_folder
# - C:\Users\Vaishnavi Giri\Desktop\@GPP\Internship\Python\week 2\package_main.py
